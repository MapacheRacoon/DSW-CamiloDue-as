# %%
# -*- coding: utf-8 -*-
from sklearn import tree
#Se crea la instancia del arbol de decision.
clf = tree.DecisionTreeClassifier()

print("Seleccione de la lista lo que mas le gusta")
print("-----------------------")
print("Lista")
print("1	Pantalones")
print("2	Vestidos")
print("3	Sandalias")
print("4	Zapatillas")
print("5	Maquillarse")
print("6	Futbol")
print("7	Le gustan las manualidades")
print("8	Peliculas romanticas")
print("9	Las motos")
print("10	Cocinar")
print("11	Jugar video juegos")
print("12	Comer")
print("13	Ir de compras")
print("-----------------------")
print("")

#Se definen los datos 1 y 2
#dato1 = [1, 7, 11]
#dato2 = [1, 2, 10]
print("=============================================================")
print("--Persona 1: Ingrese de la lista las 3 cosas que mas le gusta--")
print("=============================================================")
like1 = input("Primer Item ")
like2 = input("Segundo Item ")
like3 = input("Tercer Item ")
dato1 =[like1,like2,like3]
print("-----------------------")
print(" ")
print("==========================================================")
print("--Persona 2: Ingrese de la lista las 3 cosas que mas le gusta--")
print("==========================================================")
item1 = input("Primer Item ")
item2 = input("Segundo Item ")
item3 = input("Tercer Item ")
dato2 =[item1,item2,item3]
#Sintomas pacientes Seleccionados
print("-----------------------")
print("Cosas que mas le gustan")
print(dato1)
print("-----------------------")
print("")
print("-----------------------")
print("Item con los que mas se siente identificad@")
print(dato2)
print("-----------------------")
print("")

#Se alimenta nuestras variables X,Y para entrenar el modelo.
#[sintoma1, sintoma2,]
X = [[1, 4, 6], [13, 10, 6], [1, 13, 4], [12, 11, 6], [1, 12, 9],
     [9, 6, 10], [13, 4, 9],
     [8, 4, 9], [1, 4, 12], [6, 4, 12], [11, 1, 10], [4, 11, 13], [9, 12, 4], [8, 13, 6], [1, 6, 13], [9, 1, 4], [10, 9,2], [ 11,12,10], 
     
     [3, 8, 10], [10, 6, 2], [9, 2, 10], [13, 5, 7], [7, 10, 12], [11, 2, 5], [3, 13, 10], [2, 3, 10], [1, 5, 13], 
     [3, 5,9], [3, 5,10], [3, 5,12], [1,3,5], [1,3,9], [2,3,10], [3,3,12], [8,5,3], [10,5,13],[4,5,8], 
     [5,9,10], [5,9,12], [5,10, 12], [9,10,12]]
#La salida donde se dice si tiene covid19, gripe o resfriado
Y = ['hombre', 'hombre', 'hombre', 'hombre', 'hombre', 'hombre', 'hombre', 'hombre',
     'hombre', 'hombre', 'hombre', 'hombre', 'hombre', 'hombre', 'hombre', 'hombre', 'hombre', 'hombre', 

     'mujer', 'mujer', 'mujer', 'mujer', 'mujer', 'mujer', 'mujer', 'mujer', 'mujer', 
     'mujer', 'mujer','mujer', 'mujer', 'mujer', 'mujer', 'mujer', 'mujer', 'mujer', 'mujer', 
     'mujer', 'mujer', 'mujer', 'mujer']
#Se le pasa los datos  X y Y para entrenar el Modelo
clf = clf.fit(X, Y)

#se ejecuta la prediccion del modelo examinando el dato2
prediction = clf.predict([dato1])

#Se muestra el resultado de la prediccion de dato1
print("-----------------------")
print("-----------------------")
print("Sexo de la persona 1")
print(prediction)
print("-----------------------")
print("")
#se ejecuta la prediccion del modelo examinando el dato2
prediction = clf.predict([dato2])
#Se muestra el resultado de la prediccion de dato2
print("Sexo de la persona 2")
print(prediction)
print("-----------------------")
# Out:
# Seleccione de la lista lo que mas le gusta
# -----------------------
# Lista
# 1	Pantalones
# 2	Vestidos
# 3	Sandalias
# 4	Zapatillas
# 5	Maquillarse
# 6	Futbol
# 7	Le gustan las manualidades
# 8	Peliculas romanticas
# 9	Las motos
# 10	Cocinar
# 11	Jugar video juegos
# 12	Comer
# 13	Ir de compras
# -----------------------
#
# ...
# --Persona 1: Ingrese de la lista las 3 cosas que mas le gusta--
# ...
# Primer Item 1
# Segundo Item 4
# Tercer Item 9
# -----------------------
#
# ...
# --Persona 2: Ingrese de la lista las 3 cosas que mas le gusta--
# ...
# Primer Item 2
# Segundo Item 8
# Tercer Item 13
# -----------------------
# Cosas que mas le gustan
# ['1', '4', '9']
# -----------------------
#
# -----------------------
# Item con los que mas se siente identificad@
# ['2', '8', '13']
# -----------------------
#
# -----------------------
# -----------------------
# Sexo de la persona 1
# ['hombre']
# -----------------------
#
# Sexo de la persona 2
# ['hombre']
# -----------------------
